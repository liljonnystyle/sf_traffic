# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os, sys
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
df = pd.read_csv('bus_data/test2.csv')
df.head()
# Out:
#     REV          REPORT_TIME VEHICLE_TAG  LONGITUDE  LATITUDE  SPEED  HEADING  \
# 0  1478  05/16/2014 00:00:38           2 -122.41235  37.79940  3.889      350
# 1  1478  05/16/2014 00:01:09           2 -122.41259  37.80058  4.444      350
# 2  1478  05/16/2014 00:01:23           2 -122.41270  37.80113  3.889      348
# 3  1478  05/16/2014 00:02:14           2 -122.41357  37.80271  3.889      311
# 4  1478  05/16/2014 00:02:39           2 -122.41450  37.80333  3.333      310
#
#   TRAIN_ASSIGNMENT  PREDICTABLE
# 0             5905            1
# 1             5905            1
# 2             5905            1
# 3             5905            1
# 4             5905            1

# %%
df = df[df["LONGITUDE"] <= -122.335] # remove faulty data
df = df[df["LONGITUDE"] >= -122.541]
df = df[df["LATITUDE"] <= 37.845]
df = df[df["LATITUDE"] >= 37.68]
df.describe()
# Out:
#            REV       LONGITUDE        LATITUDE           SPEED         HEADING     PREDICTABLE
# count  1203573  1203573.000000  1203573.000000  1203573.000000  1203573.000000  1203573.000000
# mean      1478     -122.428612       37.765320        4.310525      171.109832        0.747756
# std          0        0.030377        0.025921        5.125883      113.248266        0.434301
# min       1478     -122.516560       37.680096        0.000000        0.000000        0.000000
# 25%       1478     -122.447010       37.748220        0.000000       79.000000        0.000000
# 50%       1478     -122.419960       37.768110        2.500000      175.000000        1.000000
# 75%       1478     -122.406800       37.785160        7.500000      264.000000        1.000000
# max       1478     -122.336150       37.844160       69.444000      360.000000        1.000000

# %%
plt.figure(figsize=(15,15))
ax = plt.subplot(111,axisbg='black')
#color = df['time']/df['time'].max()
plt.scatter(df['LONGITUDE'],df['LATITUDE'],linewidth=0,s=1,c='red',alpha=0.1)
