# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
df = pd.read_csv('uber_data/all.tsv',sep='\t')

#def date2int(x):
#    m = x[5:7]
#    d = x[8:10]
#    if m == '05':
#        return int(d)-17
#    elif m == '06':
#        return int(d)+14
#    elif m == '07':
#        return int(d)+34

df["year"] = [int(t[0:4]) for t in df["datetime"]]
df["month"] = [int(t[5:7]) for t in df["datetime"]]
df["day"] = [int(t[8:10]) for t in df["datetime"]]
df["hr"] = [int(t[11:13]) for t in df["datetime"]]
df["min"] = [int(t[14:16]) for t in df["datetime"]]
df["sec"] = [int(t[17:19]) for t in df["datetime"]]
df["time"] = 100*df["sec"]/60 + 10000*df["min"]/60 + df["hr"]*10000
df.head()
# Out:
#    ride                   datetime          y           x  year  month  day  \
# 0     1  2007-01-07T10:54:50+00:00  37.782551 -122.445368  2007      1    7
# 1     1  2007-01-07T10:54:54+00:00  37.782745 -122.444586  2007      1    7
# 2     1  2007-01-07T10:54:58+00:00  37.782842 -122.443688  2007      1    7
# 3     1  2007-01-07T10:55:02+00:00  37.782919 -122.442815  2007      1    7
# 4     1  2007-01-07T10:55:06+00:00  37.782992 -122.442112  2007      1    7
#
#    hr  min  sec    time
# 0  10   54   50  109083
# 1  10   54   54  109090
# 2  10   54   58  109096
# 3  10   55    2  109169
# 4  10   55    6  109176

# %%
# some rides have duplicated datapoints
df.drop_duplicates(inplace=True)

# remove remaining rides that are shorter than 5 minutes
df = df[df.groupby(['ride'])['ride'].transform('count') >= 75] 
# should actually do this by filtering trip duration, rather than value counts

# %%
df = df[df["x"] <= -120] # remove faulty data
df = df[df["x"] >= -125]
df = df[df["y"] <= 40]
df = df[df["y"] >= 35]

# %%
df.describe()
# Out:
#                 ride              y              x    year   month  \
# count  364558.000000  364558.000000  364558.000000  364558  364558
# mean    12372.579905      37.769330    -122.421149    2007       1
# std      7171.996347       0.035842       0.029606       0       0
# min         8.000000      37.530547    -122.538331    2007       1
# 25%      6130.000000      37.763369    -122.435875    2007       1
# 50%     12356.000000      37.775977    -122.421378    2007       1
# 75%     18531.000000      37.788054    -122.405883    2007       1
# max     24998.000000      37.961483    -122.187131    2007       1
#
#                  day             hr            min            sec  \
# count  364558.000000  364558.000000  364558.000000  364558.000000
# mean        4.718602       9.038872      29.485498      29.490539
# std         2.005773       7.515310      17.195951      17.297356
# min         1.000000       0.000000       0.000000       0.000000
# 25%         3.000000       3.000000      15.000000      15.000000
# 50%         5.000000       6.000000      29.000000      30.000000
# 75%         6.000000      17.000000      44.000000      44.000000
# max         7.000000      23.000000      59.000000      59.000000
#
#                 time
# count  364558.000000
# mean    95351.451607
# std     75272.653269
# min         0.000000
# 25%     30010.000000
# 50%     64585.500000
# 75%    170381.000000
# max    239931.000000

# %%
plt.figure(figsize=(15,15))
ax = plt.subplot(111,axisbg='black')
#color = df['time']/df['time'].max()
plt.scatter(df['x'],df['y'],linewidth=0,s=1,c='orange',alpha=0.1)
plt.xticks([])
plt.yticks([])
plt.axis('equal')
# Out:
# (-122.55648239784946,
#  -122.16897960215054,
#  37.508408802150527,
#  37.983621197849466)

# %%
plt.figure(figsize=(20,20))

daydict = {}
daydict[1] = 'Monday'
daydict[2] = 'Tuesday'
daydict[3] = 'Wednesday'
daydict[4] = 'Thursday'
daydict[5] = 'Friday'
daydict[6] = 'Saturday'
daydict[7] = 'Sunday'

for i in xrange(7):
    x = df[df['day'] == i+1]['x']
    y = df[df['day'] == i+1]['y']
    c = df[df['day'] == i+1]['ride']
    ax = plt.subplot(3,3,i+1,axisbg='black')
    plt.scatter(x,y,linewidth=0,s=10,c=c,alpha=0.3)
    plt.xlim(-122.6, -122.15)
    plt.ylim(37.5, 38.0)
    plt.xticks([])
    plt.yticks([])
    plt.title(daydict[i+1])

# %%
plt.figure(figsize=(20,20))

for i in xrange(7):
    x = df[df['day'] == i+1]['x']
    y = df[df['day'] == i+1]['y']
    c = df[df['day'] == i+1]['hr']
    ax = plt.subplot(3,3,i+1,axisbg='black')
    plt.scatter(x,y,linewidth=0,s=10,c=c,alpha=0.3)
    plt.xlim(-122.6, -122.15)
    plt.ylim(37.5, 38.0)
    plt.xticks([])
    plt.yticks([])
    plt.title(daydict[i+1])

# %%
df.ride.value_counts()
# Out:
# 2597     1127
# 14760     502
# 21629     436
# 4816      419
# 4110      385
# 6365      354
# 5779      347
# 23251     324
# 9697      311
# 11721     309
# 23364     296
# 21916     290
# 4876      286
# 3391      284
# 12913     279
# ...
# 14720    75
# 24585    75
# 3484     75
# 698      75
# 6464     75
# 16573    75
# 4822     75
# 22671    75
# 18803    75
# 7269     75
# 23793    75
# 23806    75
# 19708    75
# 23116    75
# 24599    75
# Length: 3416, dtype: int64

# %%
df[df['ride'] == 2597].head()
# Out:
#         ride                   datetime          y           x  year  month  \
# 116636  2597  2007-01-03T18:33:00+00:00  37.774731 -122.404152  2007      1
# 116637  2597  2007-01-03T18:33:04+00:00  37.774992 -122.403760  2007      1
# 116638  2597  2007-01-03T18:33:08+00:00  37.775273 -122.403382  2007      1
# 116639  2597  2007-01-03T18:33:12+00:00  37.775562 -122.402993  2007      1
# 116640  2597  2007-01-03T18:33:16+00:00  37.775823 -122.402690  2007      1
#
#         day  hr  min  sec    time
# 116636    3  18   33    0  185500
# 116637    3  18   33    4  185506
# 116638    3  18   33    8  185513
# 116639    3  18   33   12  185520
# 116640    3  18   33   16  185526

# %%
plt.figure(figsize=(20,15))
ax = plt.subplot(111,axisbg='black')
#color = df['time']/df['time'].max()
x = df[df['ride'] == 8]['x']
y = df[df['ride'] == 8]['y']
c = df[df['ride'] == 8]['time']

plt.scatter(x,y,linewidth=0,s=50,c=c,alpha=1)
plt.xticks([])
plt.yticks([])
plt.axis('equal')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x3fda7a0>

# %%
# Central finite difference function to estimate derivatives
def xderiv(group):
    t = group.time
    x = group.x
    "Finite difference derivative of the function f"
    n = len(x)
    d = zeros(n,'float') # assume float
    # Use centered differences for the interior points, one-sided differences for the ends
    for i in range(1,n-1):
        d[i] = (x.iloc[i+1]-x.iloc[i])/(t.iloc[i+1]-t.iloc[i])
    d[0] = (x.iloc[1]-x.iloc[0])/(t.iloc[1]-t.iloc[0])
    d[n-1] = (x.iloc[n-1]-x.iloc[n-2])/(t.iloc[n-1]-t.iloc[n-2])
    return pd.Series({'original' : group,'speedx' : d})
    #return d

def yderiv(group):
    t = group.time
    x = group.y
    "Finite difference derivative of the function f"
    n = len(x)
    d = zeros(n,'float') # assume float
    # Use centered differences for the interior points, one-sided differences for the ends
    for i in range(1,n-1):
        d[i] = (x.iloc[i+1]-x.iloc[i])/(t.iloc[i+1]-t.iloc[i])
    d[0] = (x.iloc[1]-x.iloc[0])/(t.iloc[1]-t.iloc[0])
    d[n-1] = (x.iloc[n-1]-x.iloc[n-2])/(t.iloc[n-1]-t.iloc[n-2])
    return pd.Series({'original' : group,'speedy' : d})
    #return d
    
#print df[df.ride == 14720]['time']
#print df[df.ride == 14720]['x']

#dflen = len(df)
#df['speed'] = pd.Series(np.zeros(dflen), index=df.index)
grouped = df.groupby(['ride'])
grouped.apply(xderiv)
print grouped.head()
grouped = grouped.groupby(['ride'])
grouped.apply(yderiv)
print grouped.head()
#df = pd.DataFrame(grouped)

#for name, group in grouped:
    #print name, group['time'].iloc[0]
#    speedx = deriv(group['time'], group['x'])
#    speedy = deriv(group['time'], group['y'])
#    df[df.ride == name]['speed'] = pd.Series(np.sqrt(speedx**2 + speedy**2))

#df.head()

#for name, group in df.groupby(['ride']):
#    df[df.ride == name]['accel'] = deriv(group['time'], group['speed'])

#df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-138-7998080f902d> in <module>()
#      37 print grouped.head()
#      38 grouped = grouped.groupby(['ride'])
# ---> 39 grouped.apply(yderiv)
#      40 print grouped.head()
#      41 #df = pd.DataFrame(grouped)
#
# /usr/lib/python2.7/dist-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2534             values = lib.map_infer(values, lib.Timestamp)
#    2535
# -> 2536         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2537         if isinstance(mapped[0], Series):
#    2538             from pandas.core.frame import DataFrame
#
# /usr/lib/python2.7/dist-packages/pandas/lib.so in pandas.lib.map_infer (pandas/lib.c:42848)()
#
# <ipython-input-138-7998080f902d> in yderiv(group)
#      23     for i in range(1,n-1):
#      24         d[i] = (x.iloc[i+1]-x.iloc[i])/(t.iloc[i+1]-t.iloc[i])
# ---> 25     d[0] = (x.iloc[1]-x.iloc[0])/(t.iloc[1]-t.iloc[0])
#      26     d[n-1] = (x.iloc[n-1]-x.iloc[n-2])/(t.iloc[n-1]-t.iloc[n-2])
#      27     return pd.Series({'original' : group,'speedy' : d})
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     237
#     238         if hasattr(self.obj, attr) and attr != '_cache':
# --> 239             return self._make_wrapper(attr)
#     240
#     241         raise AttributeError("'%s' object has no attribute '%s'" %
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in _make_wrapper(self, name)
#     248         f = getattr(self.obj, name)
#     249         if not isinstance(f, types.MethodType):
# --> 250             return self.apply(lambda self: getattr(self, name))
#     251
#     252         f = getattr(type(self.obj), name)
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     329         func = _intercept_function(func)
#     330         f = lambda g: func(g, *args, **kwargs)
# --> 331         return self._python_apply_general(f)
#     332
#     333     def _python_apply_general(self, f):
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     332
#     333     def _python_apply_general(self, f):
# --> 334         keys, values, mutated = self.grouper.apply(f, self.obj, self.axis)
#     335
#     336         return self._wrap_applied_output(keys, values,
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in apply(self, f, data, axis, keep_internal)
#     623
#     624         result_values = []
# --> 625         for key, (i, group) in izip(group_keys, splitter):
#     626             object.__setattr__(group, 'name', key)
#     627
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in __iter__(self)
#    2326
#    2327     def __iter__(self):
# -> 2328         sdata = self._get_sorted_data()
#    2329
#    2330         if self.ngroups == 0:
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in _get_sorted_data(self)
#    2343
#    2344     def _get_sorted_data(self):
# -> 2345         return self.data.take(self.sort_idx, axis=self.axis)
#    2346
#    2347     def _chop(self, sdata, slice_obj):
#
# /usr/lib/python2.7/dist-packages/pandas/core/series.pyc in take(self, indices, axis, convert)
#    2695         """
#    2696         indices = com._ensure_platform_int(indices)
# -> 2697         new_index = self.index.take(indices)
#    2698         new_values = self.values.take(indices)
#    2699         return Series(new_values, index=new_index, name=self.name)
#
# /usr/lib/python2.7/dist-packages/pandas/core/index.pyc in take(self, indexer, axis)
#     393         """
#     394         indexer = com._ensure_platform_int(indexer)
# --> 395         taken = self.view(np.ndarray).take(indexer)
#     396         return self._constructor(taken, name=self.name)
#     397
#
# IndexError: cannot do a non-empty take from an empty axes.
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 17080 entries, (8, 183) to (24998, 1128501)
# Data columns (total 12 columns):
# ride        17080  non-null values
# datetime    17080  non-null values
# y           17080  non-null values
# x           17080  non-null values
# year        17080  non-null values
# month       17080  non-null values
# day         17080  non-null values
# hr          17080  non-null values
# min         17080  non-null values
# sec         17080  non-null values
# time        17080  non-null values
# speed       17080  non-null values
# dtypes: float64(3), int64(8), object(1)
