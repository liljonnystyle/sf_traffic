# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('uber_data/all.tsv',sep='\t')

#def date2int(x):
#    m = x[5:7]
#    d = x[8:10]
#    if m == '05':
#        return int(d)-17
#    elif m == '06':
#        return int(d)+14
#    elif m == '07':
#        return int(d)+34

df["year"] = [int(t[0:4]) for t in df["datetime"]]
df["month"] = [int(t[5:7]) for t in df["datetime"]]
df["day"] = [int(t[8:10]) for t in df["datetime"]]
df["hr"] = [int(t[11:13]) for t in df["datetime"]]
df["min"] = [int(t[14:16]) for t in df["datetime"]]
df["sec"] = [int(t[17:19]) for t in df["datetime"]]
df["time"] = 100*df["sec"]/60 + 10000*df["min"]/60 + df["hr"]*10000 + df["day"]*240000
df.head()
# Out:
#    ride                   datetime          y           x  year  month  day  \
# 0     1  2007-01-07T10:54:50+00:00  37.782551 -122.445368  2007      1    7
# 1     1  2007-01-07T10:54:54+00:00  37.782745 -122.444586  2007      1    7
# 2     1  2007-01-07T10:54:58+00:00  37.782842 -122.443688  2007      1    7
# 3     1  2007-01-07T10:55:02+00:00  37.782919 -122.442815  2007      1    7
# 4     1  2007-01-07T10:55:06+00:00  37.782992 -122.442112  2007      1    7
#
#    hr  min  sec            time
# 0  10   54   50  1789083.333333
# 1  10   54   54  1789090.000000
# 2  10   54   58  1789096.666667
# 3  10   55    2  1789170.000000
# 4  10   55    6  1789176.666667
#
# [5 rows x 11 columns]

# %%
# some rides have duplicated datapoints
df.drop_duplicates(inplace=True)

# remove remaining rides that are shorter than 5 minutes
df = df[df.groupby(['ride'])['ride'].transform('count') >= 75] 
# should actually do this by filtering trip duration, rather than value counts

# %%
df = df[df["x"] <= -122] # remove faulty data
df = df[df["x"] >= -123]
df = df[df["y"] <= 38]
df = df[df["y"] >= 37]

# %%
df["xmiles"] = (df["x"]+123)*54.183 # convert to miles at latitude 37.7833N
df["ymiles"] = (df["y"]-37)*69.048 # convert to miles

# %%
df.describe()
# Out:
#                 ride              y              x    year   month  \
# count  364558.000000  364558.000000  364558.000000  364558  364558
# mean    12372.579905      37.769330    -122.421149    2007       1
# std      7171.996347       0.035842       0.029606       0       0
# min         8.000000      37.530547    -122.538331    2007       1
# 25%      6130.000000      37.763369    -122.435875    2007       1
# 50%     12356.000000      37.775977    -122.421378    2007       1
# 75%     18531.000000      37.788054    -122.405883    2007       1
# max     24998.000000      37.961483    -122.187131    2007       1
#
#                  day             hr            min            sec  \
# count  364558.000000  364558.000000  364558.000000  364558.000000
# mean        4.718602       9.038872      29.485498      29.490539
# std         2.005773       7.515310      17.195951      17.297356
# min         1.000000       0.000000       0.000000       0.000000
# 25%         3.000000       3.000000      15.000000      15.000000
# 50%         5.000000       6.000000      29.000000      30.000000
# 75%         6.000000      17.000000      44.000000      44.000000
# max         7.000000      23.000000      59.000000      59.000000
#
#                  time         xmiles         ymiles
# count   364558.000000  364558.000000  364558.000000
# mean   1227816.526735      31.363910      53.120707
# std     478850.204008       1.604130       2.474850
# min     240001.666667      25.014611      36.633209
# 25%     880206.666667      30.565985      52.709103
# 50%    1365509.166667      31.351476      53.579660
# 75%    1672430.000000      32.191041      54.413535
# max    1919928.333333      44.043681      66.388478
#
# [8 rows x 12 columns]

# %%
plt.figure(figsize=(15,15))
ax = plt.subplot(111,axisbg='black')
#color = df['time']/df['time'].max()
plt.scatter(df['xmiles'],df['ymiles'],linewidth=0,s=1,c='orange',alpha=0.1)
plt.xticks([])
plt.yticks([])
plt.axis('equal')
# Out:
# (24.062566549150592, 44.99572590484901, 35.144854411750423, 67.876833028249564)

# %%
plt.figure(figsize=(20,20))

daydict = {}
daydict[1] = 'Monday'
daydict[2] = 'Tuesday'
daydict[3] = 'Wednesday'
daydict[4] = 'Thursday'
daydict[5] = 'Friday'
daydict[6] = 'Saturday'
daydict[7] = 'Sunday'

for i in xrange(7):
    x = df[df['day'] == i+1]['xmiles']
    y = df[df['day'] == i+1]['ymiles']
    c = df[df['day'] == i+1]['ride']
    ax = plt.subplot(3,3,i+1,axisbg='black')
    plt.scatter(x,y,linewidth=0,s=10,c=c,alpha=0.3)
    #plt.xlim(-122.6, -122.15)
    #plt.ylim(37.5, 38.0)
    plt.xticks([])
    plt.yticks([])
    plt.title(daydict[i+1])
    plt.axis('equal')

# %%
plt.figure(figsize=(20,20))

for i in xrange(7):
    x = df[df['day'] == i+1]['xmiles']
    y = df[df['day'] == i+1]['ymiles']
    c = df[df['day'] == i+1]['hr']
    ax = plt.subplot(3,3,i+1,axisbg='black')
    plt.scatter(x,y,linewidth=0,s=10,c=c,alpha=0.3)
    #plt.xlim(-122.6, -122.15)
    #plt.ylim(37.5, 38.0)
    plt.xticks([])
    plt.yticks([])
    plt.title(daydict[i+1])
    plt.axis('equal')

# %%
df.ride.value_counts()
# Out:
# 2597     1127
# 14760     502
# 21629     436
# 4816      419
# 4110      385
# 6365      354
# 5779      347
# 23251     324
# 9697      311
# 11721     309
# 23364     296
# 21916     290
# 4876      286
# 3391      284
# 12913     279
# ...
# 14720    75
# 24585    75
# 3484     75
# 698      75
# 6464     75
# 16573    75
# 4822     75
# 22671    75
# 18803    75
# 7269     75
# 23793    75
# 23806    75
# 19708    75
# 23116    75
# 24599    75
# Length: 3416, dtype: int64

# %%
df[df['ride'] == 2597].head()
# Out:
#         ride                   datetime          y           x  year  month  \
# 116636  2597  2007-01-03T18:33:00+00:00  37.774731 -122.404152  2007      1
# 116637  2597  2007-01-03T18:33:04+00:00  37.774992 -122.403760  2007      1
# 116638  2597  2007-01-03T18:33:08+00:00  37.775273 -122.403382  2007      1
# 116639  2597  2007-01-03T18:33:12+00:00  37.775562 -122.402993  2007      1
# 116640  2597  2007-01-03T18:33:16+00:00  37.775823 -122.402690  2007      1
#
#         day  hr  min  sec           time     xmiles     ymiles
# 116636    3  18   33    0  905500.000000  32.284832  53.493626
# 116637    3  18   33    4  905506.666667  32.306072  53.511648
# 116638    3  18   33    8  905513.333333  32.326553  53.531050
# 116639    3  18   33   12  905520.000000  32.347630  53.551005
# 116640    3  18   33   16  905526.666667  32.364048  53.569027
#
# [5 rows x 13 columns]

# %%
plt.figure(figsize=(20,15))
ax = plt.subplot(111,axisbg='black')
#color = df['time']/df['time'].max()
x = df[df['ride'] == 8]['xmiles']
y = df[df['ride'] == 8]['ymiles']
c = df[df['ride'] == 8]['time']

plt.scatter(x,y,linewidth=0,s=50,c=c,alpha=1)
plt.xticks([])
plt.yticks([])
plt.axis('equal')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x109c1c3b0>

# %%
# Central finite difference function to estimate derivatives
def deriv(t,x):
    "Finite difference derivative of the function f"
    n = len(x)
    d = zeros(n,'float') # assume float
    # Use centered differences for the interior points, one-sided differences for the ends
    for i in range(1,n-1):
        d[i] = (x.iloc[i+1]-x.iloc[i])/(t.iloc[i+1]-t.iloc[i])
    d[0] = (x.iloc[1]-x.iloc[0])/(t.iloc[1]-t.iloc[0])
    d[n-1] = (x.iloc[n-1]-x.iloc[n-2])/(t.iloc[n-1]-t.iloc[n-2])
    return d

# %%
try:
    df = df.drop(['speed'],axis=1)
except:
    pass

grouped = df.groupby(['ride'])
count = 0
for name, group in grouped:
    speedx = deriv(group['time']/3600., group['xmiles']) # compute speed in mph
    speedy = deriv(group['time']/3600., group['ymiles'])
    if count == 0:
        speeddf = pd.DataFrame(np.sqrt(speedx**2 + speedy**2),index=[group.index],columns=['speed'])
    else:
        speeddf = pd.concat([speeddf,pd.DataFrame(np.sqrt(speedx**2 + speedy**2),index=[group.index],columns=['speed'])])
    count += 1

df = df.join(speeddf)
df.head()
# Out:
#      ride                   datetime          y           x  year  month  day  \
# 183     8  2007-01-03T00:52:02+00:00  37.773187 -122.421922  2007      1    3
# 184     8  2007-01-03T00:52:08+00:00  37.773043 -122.422118  2007      1    3
# 185     8  2007-01-03T00:52:13+00:00  37.773007 -122.422165  2007      1    3
# 186     8  2007-01-03T00:52:19+00:00  37.772979 -122.422219  2007      1    3
# 187     8  2007-01-03T00:52:25+00:00  37.772865 -122.422394  2007      1    3
#
#      hr  min  sec           time     xmiles     ymiles     speed
# 183   0   52    2  728670.000000  31.322000  53.387016  5.237265
# 184   0   52    8  728680.000000  31.311380  53.377073  1.537339
# 185   0   52   13  728688.333333  31.308834  53.374587  1.262497
# 186   0   52   19  728698.333333  31.305908  53.372654  4.436463
# 187   0   52   25  728708.333333  31.296426  53.364783  3.015020
#
# [5 rows x 14 columns]

# %%
try:
    df = df.drop(['accel'],axis=1)
except:
    pass

count = 0
for name, group in df.groupby(['ride']):
    accel = deriv(group['time'], group['speed']*0.44704) # compute acceleration in meter/s/s
    if count == 0:
        acceldf = pd.DataFrame(accel,index=[group.index],columns=['accel'])
    else:
        acceldf = pd.concat([acceldf,pd.DataFrame(accel,index=[group.index],columns=['accel'])])
    count += 1
df = df.join(acceldf)
df.head()
# Out:
#      ride                   datetime          y           x  year  month  day  \
# 183     8  2007-01-03T00:52:02+00:00  37.773187 -122.421922  2007      1    3
# 184     8  2007-01-03T00:52:08+00:00  37.773043 -122.422118  2007      1    3
# 185     8  2007-01-03T00:52:13+00:00  37.773007 -122.422165  2007      1    3
# 186     8  2007-01-03T00:52:19+00:00  37.772979 -122.422219  2007      1    3
# 187     8  2007-01-03T00:52:25+00:00  37.772865 -122.422394  2007      1    3
#
#      hr  min  sec           time     xmiles     ymiles     speed     accel
# 183   0   52    2  728670.000000  31.322000  53.387016  5.237265 -0.165402
# 184   0   52    8  728680.000000  31.311380  53.377073  1.537339 -0.014744
# 185   0   52   13  728688.333333  31.308834  53.374587  1.262497  0.141889
# 186   0   52   19  728698.333333  31.305908  53.372654  4.436463 -0.063544
# 187   0   52   25  728708.333333  31.296426  53.364783  3.015020  0.072363
#
# [5 rows x 15 columns]

# %%
ridenum = 19393

plt.figure(figsize=(20,20))
ax1 = plt.subplot(311,axisbg='black')
x = df[df['ride'] == ridenum]['xmiles']#.iloc[-86:]
y = df[df['ride'] == ridenum]['ymiles']#.iloc[-86:]
c = df[df['ride'] == ridenum]['time']#.iloc[-86:]
print x.iloc[0], x.iloc[-1]
print y.iloc[0], y.iloc[-1]
plt.scatter(x,y,linewidth=0,s=50,c=c,alpha=0.5)
#plt.xticks([])
#plt.yticks([])
plt.xlabel('longitude (miles from arbitrary location)')
plt.ylabel('latitude (miles from arbitrary location)')
plt.axis('equal')
#plt.colorbar()

ax2 = plt.subplot(312,axisbg='black')
x = df[df['ride'] == ridenum]['time']#.iloc[-86:]
y = df[df['ride'] == ridenum]['speed']#.iloc[-86:]
c = df[df['ride'] == ridenum]['time']#.iloc[-86:]
plt.plot(x,np.zeros(len(x)),'w--')
plt.plot(x,y,'w-')
plt.scatter(x,y,linewidth=0,s=50,c=c,alpha=1.0)
plt.xlabel('time (seconds)')
plt.ylabel('speed (mph)')
#plt.xlim(185000, 190000)
#plt.xticks([])
#plt.yticks([])

ax3 = plt.subplot(313,axisbg='black')
x = df[df['ride'] == ridenum]['time']#.iloc[-86:]
y = df[df['ride'] == ridenum]['accel']#.iloc[-86:]
c = df[df['ride'] == ridenum]['time']#.iloc[-86:]
plt.plot(x,np.zeros(len(x)),'w--')
plt.plot(x,y,'w-')
plt.scatter(x,y,linewidth=0,s=50,c=c,alpha=1.0)
plt.xlabel('time (seconds)')
plt.ylabel('acceleration (meter/s/s)')
#plt.xlim(185000, 190000)
#plt.xticks([])
#plt.yticks([])
# Out:
# 32.34779283 32.445484779
# 52.11328752 53.651953152

# %%
medspeed = pd.DataFrame(df.groupby(['ride'])['accel'].max())
medspeed.columns = ['accel']
medspeed[medspeed['accel'] < 0.3]
#medspeed.head()
# Out:
#           accel
# ride
# 826    0.261443
# 6343   0.251181
# 7909   0.278854
# 8787   0.294380
# 9334   0.244693
# 9879   0.258426
# 19393  0.166999
# 20873  0.246237
# 21436  0.249011
# 21603  0.275949
# 21740  0.285301
# 21791  0.283493
# 22061  0.287239
# 22087  0.278479
# 22587  0.294185
# 22781  0.270114
# 23080  0.290572
#
# [17 rows x 1 columns]

# %%
df[df['ride'] == ridenum][df['time'] < 50000]
# Out:
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:1686: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)
# Empty DataFrame
# Columns: [ride, datetime, y, x, year, month, day, hr, min, sec, time, xmiles, ymiles, speed, accel]
# Index: []
#
# [0 rows x 15 columns]

# %%
df.to_csv("uber_data/clean.csv")
